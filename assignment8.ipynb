# %% [markdown]
# Data Visualization I
# 1. Use the inbuilt dataset 'titanic'. The dataset contains 891 rows and contains information
# about the passengers who boarded the unfortunate Titanic ship. Use the Seaborn library to
# see if we can find any patterns in the data.
# 2. Write a code to check how the price of the ticket (column name: 'fare') for each passenger
# is distributed by plotting a histogram.

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('/content/drive/MyDrive/TE/Temp/Dsdba/Titanic-Dataset.csv')
df.head(1000)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df['Cabin'].unique()  # we can drop this doesn t matter much as it contain null value
# Out:
# array([nan, 'C85', 'C123', 'E46', 'G6', 'C103', 'D56', 'A6',
#        'C23 C25 C27', 'B78', 'D33', 'B30', 'C52', 'B28', 'C83', 'F33',
#        'F G73', 'E31', 'A5', 'D10 D12', 'D26', 'C110', 'B58 B60', 'E101',
#        'F E69', 'D47', 'B86', 'F2', 'C2', 'E33', 'B19', 'A7', 'C49', 'F4',
#        'A32', 'B4', 'B80', 'A31', 'D36', 'D15', 'C93', 'C78', 'D35',
#        'C87', 'B77', 'E67', 'B94', 'C125', 'C99', 'C118', 'D7', 'A19',
#        'B49', 'D', 'C22 C26', 'C106', 'C65', 'E36', 'C54',
#        'B57 B59 B63 B66', 'C7', 'E34', 'C32', 'B18', 'C124', 'C91', 'E40',
#        'T', 'C128', 'D37', 'B35', 'E50', 'C82', 'B96 B98', 'E10', 'E44',
#        'A34', 'C104', 'C111', 'C92', 'E38', 'D21', 'E12', 'E63', 'A14',
#        'B37', 'C30', 'D20', 'B79', 'E25', 'D46', 'B73', 'C95', 'B38',
#        'B39', 'B22', 'C86', 'C70', 'A16', 'C101', 'C68', 'A10', 'E68',
#        'B41', 'A20', 'D19', 'D50', 'D9', 'A23', 'B50', 'A26', 'D48',
# ...

# %%
sns.countplot(x='Survived', hue='Pclass', data=df,color='blue')
# sns.countplot(x='Survived', hue='Sex', data=df,alpha=0.5,color='red')
plt.legend()
plt.show()
# Out:
# <ipython-input-39-a44f7fa6f5f1>:1: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:blue'` for the same effect.
#
#   sns.countplot(x='Survived', hue='Pclass', data=df,color='blue')

# %%
survived_by_class = df.groupby(['Survived', 'Pclass']).size().unstack()
print(survived_by_class)

survived_by_class.plot(kind='bar', stacked=True)

plt.title('survival count by class')
plt.xlabel('Survived')
plt.ylabel('Count')
plt.show()
# Out:
# Pclass      1   2    3
# Survived
# 0          80  97  372
# 1         136  87  119

# %%
sns.set(style="whitegrid")

# Histograms
df[['Age', 'Fare', 'SibSp', 'Parch']].hist(bins=10, figsize=(10, 8), layout=(2, 2))
plt.suptitle('Histograms of Numerical Variables', y=1.02)
plt.show()

# %%
sns.histplot(df['Age'],bins=10)
# sns.distplot(df['Age'],bins=10)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
# sns.set(style="whitegrid")

# Create the distribution plot with hue for survival
# plt.figure(figsize=(10, 6))

sns.histplot(df[df['Survived'] == 0]['Age'], bins=10, color='red', label='Not Survived')
sns.histplot(df[df['Survived'] == 1]['Age'], bins=10, color='blue', label='Survived')

plt.title('Distribution of Age Colored by Survival')
plt.xlabel('Age')
# plt.legend()
plt.show()

# %%
age_group_counts = df.groupby('Age')['Survived'].agg(['count', 'sum'])
age_group_counts['survival_ratio'] = age_group_counts['sum'] / age_group_counts['count'] * 100

# Plot the ratio of survivors upon total count of each age group
plt.figure(figsize=(12, 6))
sns.barplot(x=age_group_counts.index, y='survival_ratio', data=age_group_counts, color='skyblue')
plt.title('Ratio of Survivors Upon Total Count by Age Group')
plt.xlabel('Age')
plt.ylabel('Survival Ratio (%)')
plt.xticks(rotation=90)  # Rotate x-labels for better readability
plt.tight_layout()
plt.show()

# %%
# percentage of survivers according to age group
df['Age_bin'] = pd.cut(df['Age'], bins=range(0, 90, 10), right=False)

# Calculate the ratio of survivors to total count within each age bin
age_bin_counts = df.groupby('Age_bin')['Survived'].agg(['count', 'sum'])
print(age_bin_counts)
age_bin_counts['survival_ratio'] = age_bin_counts['sum'] / age_bin_counts['count'] * 100
print(age_bin_counts)

# Plot the ratio of survivors upon total count of each age bin
plt.figure(figsize=(10, 6))
sns.barplot(x=age_bin_counts.index.astype(str), y='survival_ratio', data=age_bin_counts, color='skyblue')
plt.title('Ratio of Survivors Upon Total Count by Age Group (Bins of 10)')
plt.xlabel('Age Group')
plt.ylabel('Survival Ratio (%)')
# plt.xticks(rotation=45)  # Rotate x-labels for better readability
plt.tight_layout()
plt.show()
# Out:
#           count  sum
# Age_bin
# [0, 10)      62   38
# [10, 20)    102   41
# [20, 30)    220   77
# [30, 40)    167   73
# [40, 50)     89   34
# [50, 60)     48   20
# [60, 70)     19    6
# [70, 80)      6    0
#           count  sum  survival_ratio
# Age_bin
# [0, 10)      62   38       61.290323
# [10, 20)    102   41       40.196078
# [20, 30)    220   77       35.000000
# [30, 40)    167   73       43.712575
# [40, 50)     89   34       38.202247
# [50, 60)     48   20       41.666667
# [60, 70)     19    6       31.578947
# [70, 80)      6    0        0.000000

# %%
pclass_counts = df.groupby('Pclass')['Survived'].agg(['count', 'sum'])
pclass_counts['survival_ratio'] = pclass_counts['sum'] / pclass_counts['count'] * 100

# Plot the ratio of survivors upon total count of each passenger class
plt.figure(figsize=(8, 6))
sns.barplot(x=pclass_counts.index, y='survival_ratio', data=pclass_counts, palette='pastel')
plt.title('Ratio of Survivors Upon Total Count by Passenger Class')
plt.xlabel('Passenger Class')
plt.ylabel('Survival Ratio (%)')
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-48-e0005a5f5bfc>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=pclass_counts.index, y='survival_ratio', data=pclass_counts, palette='pastel')

# %%
pclass_counts = df.groupby('Sex')['Survived'].agg(['count', 'sum'])
pclass_counts['survival_ratio'] = pclass_counts['sum'] / pclass_counts['count'] * 100

# Plot the ratio of survivors upon total count of each passenger class
plt.figure(figsize=(8, 6))
sns.barplot(x=pclass_counts.index, y='survival_ratio', data=pclass_counts, palette='pastel')
plt.title('Ratio of Survivors Upon Total Count by Passenger Class')
plt.xlabel('Passenger Class')
plt.ylabel('Survival Ratio (%)')
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-49-98fb531d7b7b>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=pclass_counts.index, y='survival_ratio', data=pclass_counts, palette='pastel')

# %%
# Create a new variable indicating whether the passenger was single or with parent/child
# df['Single_or_with_Parch'] = df['Parch'].apply(lambda x: 'Single' if x == 0 else 'With Parent/Child')

# Plot the count of passengers who were single or with parent/child
plt.figure(figsize=(8, 6))
sns.countplot(x='Parch', data=df, palette='Set2',hue='Survived')
plt.title('Passengers Count: Single vs. With Parent/Child')
plt.xlabel('Passenger Type')
plt.ylabel('Count')
plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(1, 3, figsize=(15, 5))
sns.countplot(x='Survived', data=df, ax=axes[0])
sns.countplot(x='Pclass', data=df, ax=axes[1])
sns.countplot(x='Sex', data=df, ax=axes[2])
fig.suptitle('Bar Charts of Categorical Variables')
plt.show()

# %%
# df['Age'] = df['Age'].replace('NaN', np.nan, regex=True)

# %%
mean_age = df['Age'].mean();
print(mean_age)
# Out:
# 29.69911764705882

# %%
df['Age'].fillna(mean_age , inplace=True)

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# Age_bin        178
# dtype: int64

# %%
df.head(1000)

# %%
Age = df['Age'].dropna()


plt.figure(figsize=(8, 6))
plt.hist(Age , bins=100, color='skyblue', edgecolor='black')
plt.title('Histogram of Age')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.grid(axis='y')  # Show gridlines on y-axis
# plt.tight_layout()
# plt.show()

# %%
# Plot a histogram of the ticket prices (fare)
plt.figure(figsize=(10, 6))
plt.hist(df['Fare'], bins=20, color='skyblue', edgecolor='black')
plt.title('Distribution of Ticket Prices')
plt.xlabel('Fare')
plt.ylabel('Frequency')
plt.grid(True)  # Add grid lines for better readability
plt.show()

# %%
sns.distplot(df['Age'])
plt.show()
# Out:
# <ipython-input-64-29923ba59938>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'])

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.lineplot(x="Pclass", y="Fare", data=df)
plt.show()

# %%
sns.lineplot(x="Sex", y="Fare", data=df)
plt.show()

# %%
def gender_encoder(value):
    if (value == "male"):
        return 1
    elif (value == "female"):
        return 0
    else:
        return value

df["Sex"] = df["Sex"].map(gender_encoder)
df.head()
temp = df.groupby(["Pclass","Sex","Survived"]).agg(['count'])
# print(temp)
temp
# te = temp["Pclass"]
tee=temp["PassengerId"]
print(tee)
tee
# print(tee)
tee.plot(kind='bar')
# Out:
#                      count
# Pclass Sex Survived
# 1      0   0             3
#            1            91
#        1   0            77
#            1            45
# 2      0   0             6
#            1            70
#        1   0            91
#            1            17
# 3      0   0            72
#            1            72
#        1   0           300
#            1            47
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-104-8b7b4c43dc44> in <cell line: 19>()
#      17 tee
#      18 # print(tee)
# ---> 19 tee.plot(kind='bar',hue="Sex")
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     973                     data.columns = label_name
#     974
# --> 975         return plot_backend.plot(data, kind=kind, **kwargs)
#     976
#     977     __call__.__doc__ = __doc__
#
# ...

# %%
sns.countplot(x="Sex",hue="Pclass",data=df)
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x="Sex", hue="Pclass", data=df, palette='Set1', hue_order=[1, 2, 3])
plt.title('Passenger Count by Sex, Passenger Class, and Survival Status')
plt.xlabel('Sex')
plt.ylabel('Count')
plt.legend(title='Pclass', loc='upper right')
plt.grid(True)  # Add grid lines for better readability
plt.show()

# %%
sns.relplot(data = df , x ="PassengerId" , y="Fare", hue="Pclass" , kind ="line");

# %%
df.info()

# %%
#  num_data= df[['Survived']]
# num_data= df[['Fare']]
sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-109-d5da701dbcd7> in <cell line: 3>()
#       1 #  num_data= df[['Survived']]
#       2 # num_data= df[['Fare']]
# ----> 3 sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in corr(self, method, min_periods, numeric_only)
#   10052         cols = data.columns
#   10053         idx = cols.copy()
# > 10054         mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10055
#   10056         if method == "pearson":
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in to_numpy(self, dtype, copy, na_value)
#    1836         if dtype is not None:
#    1837             dtype = np.dtype(dtype)
# -> 1838         result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1839         if result.dtype is not dtype:
# ...

# %%
fare = df['Fare'].dropna()
plt.figure(figsize=(8, 6))
plt.hist(fare , bins=100, color='skyblue', edgecolor='black')
plt.title('Histogram of fare')
plt.xlabel('fare')
plt.ylabel('Frequency')
plt.grid(axis='y')

# %%
# Import seaborn
import seaborn as sns

# Apply the default theme
sns.set_theme()

# Load an example dataset
tips = sns.load_dataset("tips")

# Create a visualization
sns.relplot(
    data=tips,
    x="total_bill", y="tip", col="time",
    hue="smoker", style="smoker", size="size",
)
