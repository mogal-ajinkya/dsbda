# %% [markdown]
# Descriptive Statistics - Measures of Central Tendency and variability
# Perform the following operations on any open source dataset (e.g., data.csv)
# 1. Provide summary statistics (mean, median, minimum, maximum, standard deviation) for
# a dataset (age, income etc.) with numeric variables grouped by one of the qualitative
# (categorical) variable. For example, if your categorical variable is age groups and
# quantitative variable is income, then provide summary statistics of income grouped by the
# age groups. Create a list that contains a numeric value for each response to the categorical
# variable.
# 2. Write a Python program to disp

# %%
print("hello")
import pandas as pd
import numpy as np

# df = pd.read_csv('/content/sample_data/StudentsPerformance_modified.csv')
df = pd.read_csv('/content/drive/MyDrive/TE/Temp/Dsdba/Iris.csv')
# Out:
# hello

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
df['SepalLengthCm'].describe()
# Out:
# count    150.000000
# mean       5.843333
# std        0.828066
# min        4.300000
# 25%        5.100000
# 50%        5.800000
# 75%        6.400000
# max        7.900000
# Name: SepalLengthCm, dtype: float64

# %%
n_df = df.groupby('Species').describe()

# %%
print(n_df.to_string())
# Out:
#                    Id                                                       SepalLengthCm                                             SepalWidthCm                                               PetalLengthCm                                              PetalWidthCm
#                 count   mean       std    min     25%    50%     75%    max         count   mean       std  min    25%  50%  75%  max        count   mean       std  min    25%  50%    75%  max         count   mean       std  min  25%   50%    75%  max        count   mean       std  min  25%  50%  75%  max
# Species
# Iris-setosa      50.0   25.5  14.57738    1.0   13.25   25.5   37.75   50.0          50.0  5.006  0.352490  4.3  4.800  5.0  5.2  5.8         50.0  3.418  0.381024  2.3  3.125  3.4  3.675  4.4          50.0  1.464  0.173511  1.0  1.4  1.50  1.575  1.9         50.0  0.244  0.107210  0.1  0.2  0.2  0.3  0.6
# ...

# %%
n_df = df.groupby('Species').describe().sum()
n_df
# Out:
# Id             count    150.000000
#                mean     226.500000
#                std       43.732139
#                min      153.000000
#                25%      189.750000
#                50%      226.500000
#                75%      263.250000
#                max      300.000000
# SepalLengthCm  count    150.000000
#                mean      17.530000
#                std        1.504540
#                min       14.100000
#                25%       16.625000
#                50%       17.400000
#                75%       18.400000
#                max       20.700000
# SepalWidthCm   count    150.000000
#                mean       9.162000
#                std        1.017319
#                min        6.500000
#                25%        8.450000
#                50%        9.200000
#                75%        9.850000
#                max       11.600000
# PetalLengthCm  count    150.000000
#                mean      11.276000
#                std        1.195317
# ...

# %%
df.groupby('Species').describe()
# Out:
#                    Id                                                        \
#                 count   mean       std    min     25%    50%     75%    max
# Species
# Iris-setosa      50.0   25.5  14.57738    1.0   13.25   25.5   37.75   50.0
# Iris-versicolor  50.0   75.5  14.57738   51.0   63.25   75.5   87.75  100.0
# Iris-virginica   50.0  125.5  14.57738  101.0  113.25  125.5  137.75  150.0
#
#                 SepalLengthCm         ... PetalLengthCm      PetalWidthCm  \
#                         count   mean  ...           75%  max        count
# Species                               ...
# Iris-setosa              50.0  5.006  ...         1.575  1.9         50.0
# Iris-versicolor          50.0  5.936  ...         4.600  5.1         50.0
# Iris-virginica           50.0  6.588  ...         5.875  6.9         50.0
#
#
#                   mean       std  min  25%  50%  75%  max
# Species
# Iris-setosa      0.244  0.107210  0.1  0.2  0.2  0.3  0.6
# ...

# %%
df.isnull()
# Out:
#         Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0    False          False         False          False         False    False
# 1    False          False         False          False         False    False
# 2    False          False         False          False         False    False
# 3    False          False         False          False         False    False
# 4    False          False         False          False         False    False
# ..     ...            ...           ...            ...           ...      ...
# 145  False          False         False          False         False    False
# 146  False          False         False          False         False    False
# 147  False          False         False          False         False    False
# 148  False          False         False          False         False    False
# 149  False          False         False          False         False    False
#
# [150 rows x 6 columns]

# %%
df.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
df.head(10)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
# 5   6            5.4           3.9            1.7           0.4  Iris-setosa
# 6   7            4.6           3.4            1.4           0.3  Iris-setosa
# 7   8            5.0           3.4            1.5           0.2  Iris-setosa
# 8   9            4.4           2.9            1.4           0.2  Iris-setosa
# 9  10            4.9           3.1            1.5           0.1  Iris-setosa

# %%
import matplotlib.pyplot as plt

df.hist(bins=100, color='skyblue', edgecolor='black')
# Out:
# array([[<Axes: title={'center': 'Id'}>,
#         <Axes: title={'center': 'SepalLengthCm'}>],
#        [<Axes: title={'center': 'SepalWidthCm'}>,
#         <Axes: title={'center': 'PetalLengthCm'}>],
#        [<Axes: title={'center': 'PetalWidthCm'}>, <Axes: >]], dtype=object)

# %%
PetalLengthCm = df['PetalLengthCm'].dropna()

plt.hist(PetalLengthCm , bins=100, color='skyblue', edgecolor='black')
plt.title('Histogram of PetalLengthCm')
plt.xlabel('SepalLengthCm')
plt.ylabel('Frequency')
plt.grid(axis='y')  # Show gridlines on y-axis
# plt.tight_layout()
# plt.show()

# %%
SepalLengthCm = df['SepalLengthCm'].dropna()

plt.figure(figsize=(8, 6))
plt.hist(SepalLengthCm , bins=100, color='skyblue', edgecolor='black')
plt.title('Histtogram of SepalLengthCm')
plt.xlabel('SepalLengthCm')
plt.ylabel('Frequency')
plt.grid(axis='y')  # Show gridlines on y-axis
# plt.tight_layout()
# plt.show()

# %%
SepalWidthCm = df['SepalWidthCm'].dropna()

plt.figure(figsize=(8, 6))
plt.hist(SepalWidthCm , bins=100, color='skyblue', edgecolor='black')
plt.title('Histogram of SepalWidthCm')
plt.xlabel('SepalLengthCm')
plt.ylabel('Frequency')
plt.grid(axis='y')  # Show gridlines on y-axis
# plt.tight_layout()
# plt.show()

# %%
PetalWidthCm = df['PetalWidthCm'].dropna()

plt.figure(figsize=(8, 6))
plt.hist(PetalWidthCm , bins=100, color='skyblue', edgecolor='black')
plt.title('Histogram of PetalWidthCm')
plt.xlabel('SepalLengthCm')
plt.ylabel('Frequency')
plt.grid(axis='y')  # Show gridlines on y-axis
# plt.tight_layout()
# plt.show()

# %%
df.shape
# Out:
# (150, 6)

# %%
df.plot()
# Out:
# <Axes: >

# %%
df.plot.box()
# Out:
# <Axes: >

# %%
df.plot.scatter(x = "SepalLengthCm" , y = "SepalWidthCm" )
# seqal length and sepal width are not related in any way
# Out:
# <Axes: xlabel='SepalLengthCm', ylabel='SepalWidthCm'>

# %%
df.plot.scatter(x = "PetalLengthCm" , y = "PetalWidthCm" )
# petal length and petal width are positively correlated and forming two groups
# Out:
# <Axes: xlabel='PetalLengthCm', ylabel='PetalWidthCm'>

# %%
df.plot.scatter(x = "SepalWidthCm" , y = "PetalWidthCm" )
# Out:
# <Axes: xlabel='SepalWidthCm', ylabel='PetalWidthCm'>

# %%
df.plot.scatter(x = "SepalLengthCm" , y = "PetalLengthCm" )
# they are positively correlated
# Out:
# <Axes: xlabel='SepalLengthCm', ylabel='PetalLengthCm'>

# %%
print(f"Original DataFrame size: {len(df)} rows")
# Out:
# Original DataFrame size: 150 rows

# %%
def remove_outliers_iqr(dataframe, column):
    Q1 = dataframe[column].quantile(0.25)
    Q3 = dataframe[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    filtered_df = dataframe[(dataframe[column] >= lower_bound) & (dataframe[column] <= upper_bound)]
    return filtered_df

score_columns = ['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm']

for column in score_columns:
    n_df = remove_outliers_iqr(df, column)

n_df
print(f"after DataFrame size: {len(df)} rows")

# their are no outliers in the given datat
# Out:
# after DataFrame size: 150 rows

# %%
df.plot.scatter(x = "SepalLengthCm" , y = "SepalWidthCm" )
# Out:
# <Axes: xlabel='SepalLengthCm', ylabel='SepalWidthCm'>

# %%
df.corr(numeric_only=True)

# spel length and petal length are postively correlated
# and petallength and petalwidth are positively correlated
# Out:
#                      Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  \
# Id             1.000000       0.716676     -0.397729       0.882747
# SepalLengthCm  0.716676       1.000000     -0.109369       0.871754
# SepalWidthCm  -0.397729      -0.109369      1.000000      -0.420516
# PetalLengthCm  0.882747       0.871754     -0.420516       1.000000
# PetalWidthCm   0.899759       0.817954     -0.356544       0.962757
#
#                PetalWidthCm
# Id                 0.899759
# SepalLengthCm      0.817954
# SepalWidthCm      -0.356544
# PetalLengthCm      0.962757
# PetalWidthCm       1.000000

# %%
import seaborn
import matplotlib.pyplot as plt

# df = seaborn.load_dataset('tips')
seaborn.pairplot(df)
plt.show()
